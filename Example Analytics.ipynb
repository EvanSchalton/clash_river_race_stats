# %%
import boto3
from boto3.dynamodb.conditions import Key

# %%
from datetime import datetime, timedelta

# %%
import json

# %%
DATABASE_NAME = "RiverRaceStats"

# %%
SavageOctopus='#GPR2JUQ'
SavageOctopusFeeder = '#Y00PPQ8Y'

# %%
def clanDataBetween(clan_tag, date_range, tableName=DATABASE_NAME):
    '''
    Query data from the database
    '''
    
    # Create a client
    dynamodb = boto3.resource('dynamodb')

    # Connect to the table
    table = dynamodb.Table(tableName)
    
    # Pass a query
    response = table.query(
        KeyConditionExpression=Key('clanTag').eq(clan_tag) & Key('pullTime').between(date_range[0], date_range[1])
    )
    return response['Items']

# %%
print('The Database stores everything in "ISO" format, this is the current time:')
datetime.now().isoformat()
# Out:
# The Database stores everything in "ISO" format, this is the current time:
# '2020-11-04T16:56:30.394936'

# %%
timeNow = datetime.now()
_30DaysAgo = timeNow - timedelta(days=30) #Can't start a variable with a number

targetRange = [_30DaysAgo.isoformat(), timeNow.isoformat()]

print("Our range looks like this:\n\t", targetRange)
# Out:
# Our range looks like this:
# 	 ['2020-10-05T16:56:30.581453', '2020-11-04T16:56:30.581453']

# %%
# Now let's get some data:
data = clanDataBetween(
    clan_tag = SavageOctopus,
    date_range = targetRange
)

# %%
print("Here's what we got:")
for record in data:
    print(f"{record['pullTime']}:  {record['clanTag']}")
# Out:
# Here's what we got:
# 2020-11-04T15:57:46.923597:  #GPR2JUQ

# %% [markdown]
# ## You can see all of the data here:

# %%
data
# Out:
# [{'clanTag': '#GPR2JUQ',
#   'pullTime': '2020-11-04T15:57:46.923597',
#   'data': {'clan': {'finishTime': '20201104T053720.000Z',
#     'badgeId': Decimal('16000154'),
#     'name': '#SAVAGE OCTOPUS',
#     'repairPoints': Decimal('0'),
#     'tag': '#GPR2JUQ',
#     'clanScore': Decimal('3270'),
#     'fame': Decimal('52944'),
#     'participants': [{'name': 'deke',
#       'repairPoints': Decimal('0'),
#       'tag': '#89RCVQ9RG',
#       'fame': Decimal('0')},
#      {'name': 'AlexPrince',
#       'repairPoints': Decimal('0'),
#       'tag': '#889YULY2P',
#       'fame': Decimal('0')},
#      {'name': 'Basher',
#       'repairPoints': Decimal('0'),
#       'tag': '#PR28UJGJR',
#       'fame': Decimal('0')},
#      {'name': 'Kalypso♋',
#       'repairPoints': Decimal('0'),
#       'tag': '#PR0228R8',
#       'fame': Decimal('208')},
#      {'name': 'LeggoMyEggo',
#       'repairPoints': Decimal('0'),
#       'tag': '#9YPY00JY',
#       'fame': Decimal('407')},
#      {'name': '☘️☘️☘️☘️☘️',
#       'repairPoints': Decimal('0'),
#       'tag': '#9VJPP08VC',
#       'fame': Decimal('492')},
#      {'name': '#SO King Krabby',
#       'repairPoints': Decimal('0'),
#       'tag': '#8YQY0JUP',
#       'fame': Decimal('505')},
#      {'name': 'amb',
#       'repairPoints': Decimal('0'),
#       'tag': '#UJL02PUP',
#       'fame': Decimal('517')},
#      {'name': '4lb3rt',
#       'repairPoints': Decimal('0'),
#       'tag': '#899JGCCPJ',
#       'fame': Decimal('613')},
#      {'name': 'Hofee',
#       'repairPoints': Decimal('0'),
#       'tag': '#2P9LQYUV',
#       'fame': Decimal('684')},
#      {'name': 'Zambie:)',
#       'repairPoints': Decimal('0'),
#       'tag': '#JPRUR9VV',
#       'fame': Decimal('693')},
#      {'name': '<c1>MANE',
#       'repairPoints': Decimal('0'),
#       'tag': '#8LY9YLVJQ',
#       'fame': Decimal('810')},
#      {'name': 'PrinceFrederick',
#       'repairPoints': Decimal('0'),
#       'tag': '#9Q22RVGJ',
#       'fame': Decimal('823')},
#      {'name': 'Mouf',
#       'repairPoints': Decimal('0'),
#       'tag': '#8L88PQQY',
#       'fame': Decimal('842')},
#      {'name': 'HectorDaNector',
#       'repairPoints': Decimal('0'),
#       'tag': '#Q8R09VP',
#       'fame': Decimal('892')},
#      {'name': 'crazy',
#       'repairPoints': Decimal('0'),
#       'tag': '#LUG8UG9L',
#       'fame': Decimal('901')},
#      {'name': 'GABRIEL :v',
#       'repairPoints': Decimal('0'),
#       'tag': '#2YJV0PUCC',
#       'fame': Decimal('963')},
#      {'name': 'mooseknuckles',
#       'repairPoints': Decimal('0'),
#       'tag': '#28LLP80CL',
#       'fame': Decimal('984')},
#      {'name': 'gus',
#       'repairPoints': Decimal('0'),
#       'tag': '#L0YUJQQU',
#       'fame': Decimal('986')},
#      {'name': 'Zoroth',
#       'repairPoints': Decimal('0'),
#       'tag': '#88RJ20LL',
#       'fame': Decimal('1030')},
#      {'name': 'N.T.L',
#       'repairPoints': Decimal('0'),
#       'tag': '#R8CYQQ8',
#       'fame': Decimal('1127')},
#      {'name': 'fadedsun',
#       'repairPoints': Decimal('0'),
#       'tag': '#2LQ29JY9Y',
#       'fame': Decimal('1134')},
#      {'name': 'Gabino',
#       'repairPoints': Decimal('0'),
#       'tag': '#9CUP08J2',
#       'fame': Decimal('1144')},
#      {'name': 'Codi',
#       'repairPoints': Decimal('0'),
#       'tag': '#9CVYJ8QL',
#       'fame': Decimal('1173')},
#      {'name': 'HankMccoy',
#       'repairPoints': Decimal('0'),
#       'tag': '#V2UCPRLJ',
#       'fame': Decimal('1196')},
#      {'name': 'batninja',
#       'repairPoints': Decimal('0'),
#       'tag': '#22C08RP9L',
#       'fame': Decimal('1224')},
#      {'name': 'All_Things_Pnw',
#       'repairPoints': Decimal('0'),
#       'tag': '#2UQJJQPV',
#       'fame': Decimal('1237')},
#      {'name': 'T-Rid',
#       'repairPoints': Decimal('0'),
#       'tag': '#9J9QL9L8',
#       'fame': Decimal('1239')},
#      {'name': 'updog',
#       'repairPoints': Decimal('0'),
#       'tag': '#2J998UR99',
#       'fame': Decimal('1245')},
#      {'name': 'Classy Assassin',
#       'repairPoints': Decimal('0'),
#       'tag': '#9Q9YJQY08',
#       'fame': Decimal('1301')},
#      {'name': 'GucciAlfredo',
#       'repairPoints': Decimal('0'),
#       'tag': '#2RJUVVVG2',
#       'fame': Decimal('1304')},
#      {'name': 'MotionTrap',
#       'repairPoints': Decimal('0'),
#       'tag': '#8J29PC8J',
#       'fame': Decimal('1318')},
#      {'name': 'Savage',
#       'repairPoints': Decimal('0'),
#       'tag': '#YGYY8GCY8',
#       'fame': Decimal('1318')},
#      {'name': 'brandon',
#       'repairPoints': Decimal('0'),
#       'tag': '#P0P80YJ8',
#       'fame': Decimal('1328')},
#      {'name': 'mikehawk',
#       'repairPoints': Decimal('0'),
#       'tag': '#PPCCV99GR',
#       'fame': Decimal('1400')},
#      {'name': 'andrewnett',
#       'repairPoints': Decimal('0'),
#       'tag': '#2L2YP8UC2',
#       'fame': Decimal('1438')},
#      {'name': 'Marqueezy',
#       'repairPoints': Decimal('0'),
#       'tag': '#2RJ0G8YL',
#       'fame': Decimal('1509')},
#      {'name': 'jpfanatic',
#       'repairPoints': Decimal('0'),
#       'tag': '#8Y20GP9J',
#       'fame': Decimal('1548')},
#      {'name': 'Krystorr',
#       'repairPoints': Decimal('0'),
#       'tag': '#L0G280JY',
#       'fame': Decimal('1560')},
#      {'name': 'ClassyBarbarian',
#       'repairPoints': Decimal('0'),
#       'tag': '#2LRP8YC8G',
#       'fame': Decimal('1584')},
#      {'name': 'ImSoBuilt',
#       'repairPoints': Decimal('0'),
#       'tag': '#PPLRJ2C',
#       'fame': Decimal('1599')},
#      {'name': 'dream',
#       'repairPoints': Decimal('0'),
#       'tag': '#2V9LVLQY',
#       'fame': Decimal('1614')},
#      {'name': 'brnurshps',
#       'repairPoints': Decimal('0'),
#       'tag': '#GQCGJY9J',
#       'fame': Decimal('1644')},
#      {'name': 'krispytreats',
#       'repairPoints': Decimal('0'),
#       'tag': '#Q08QJJJ8',
#       'fame': Decimal('1724')},
#      {'name': 'SuperSamoanBlue',
#       'repairPoints': Decimal('0'),
#       'tag': '#90CRR28Q',
#       'fame': Decimal('1853')},
#      {'name': 'ESchalton',
#       'repairPoints': Decimal('0'),
#       'tag': '#2G9V8P2PJ',
#       'fame': Decimal('1854')},
#      {'name': 'Wolfy',
#       'repairPoints': Decimal('0'),
#       'tag': '#202PVQRUP',
#       'fame': Decimal('1971')},
#      {'name': 'Bruce',
#       'repairPoints': Decimal('0'),
#       'tag': '#VQ8PY8VR',
#       'fame': Decimal('2008')}]},
#    'clans': [{'finishTime': '20201103T230917.000Z',
#      'badgeId': Decimal('16000028'),
#      'name': 'CAPITAL TURIA!!',
#      'repairPoints': Decimal('0'),
#      'tag': '#2QP0JQVG',
#      'clanScore': Decimal('3230'),
#      'fame': Decimal('60171'),
#      'participants': [{'name': 'lolito14',
#        'repairPoints': Decimal('0'),
#        'tag': '#YP2JC2LQ',
#        'fame': Decimal('0')},
#       {'name': 'theundertaker',
#        'repairPoints': Decimal('0'),
#        'tag': '#LQLQYVVLJ',
#        'fame': Decimal('0')},
#       {'name': '8bits',
#        'repairPoints': Decimal('0'),
#        'tag': '#VJRVRQQ',
#        'fame': Decimal('0')},
#       {'name': 'yhya',
#        'repairPoints': Decimal('0'),
#        'tag': '#LJJJP809L',
#        'fame': Decimal('156')},
#       {'name': 'Ricky',
#        'repairPoints': Decimal('0'),
#        'tag': '#9080LYUL',
#        'fame': Decimal('250')},
#       {'name': '®©™Martins™®©',
#        'repairPoints': Decimal('0'),
#        'tag': '#Y8JLG2088',
#        'fame': Decimal('310')},
#       {'name': 'aaronpp14',
#        'repairPoints': Decimal('0'),
#        'tag': '#8JVV0YGV',
#        'fame': Decimal('457')},
#       {'name': 'MRAK_BMN',
#        'repairPoints': Decimal('0'),
#        'tag': '#RRVPUP0Y',
#        'fame': Decimal('473')},
#       {'name': 'ARTICUS',
#        'repairPoints': Decimal('0'),
#        'tag': '#LULQ909L',
#        'fame': Decimal('544')},
#       {'name': 'Fornudo',
#        'repairPoints': Decimal('0'),
#        'tag': '#PYQ9CUQ',
#        'fame': Decimal('587')},
#       {'name': 'elvict0r612',
#        'repairPoints': Decimal('0'),
#        'tag': '#2L88L0YUC',
#        'fame': Decimal('612')},
#       {'name': 'mdemacs_',
#        'repairPoints': Decimal('0'),
#        'tag': '#2J8PJ9P9Y',
#        'fame': Decimal('673')},
#       {'name': 'Juanjo',
#        'repairPoints': Decimal('0'),
#        'tag': '#8QJUYVV08',
#        'fame': Decimal('701')},
#       {'name': 'ragnar',
#        'repairPoints': Decimal('0'),
#        'tag': '#8YP9JLJYY',
#        'fame': Decimal('766')},
#       {'name': 'agui',
#        'repairPoints': Decimal('0'),
#        'tag': '#2UPPLRGJL',
#        'fame': Decimal('895')},
#       {'name': 'Mediometro',
#        'repairPoints': Decimal('0'),
#        'tag': '#88YY0LCCV',
#        'fame': Decimal('960')},
#       {'name': 'Miguel',
#        'repairPoints': Decimal('0'),
#        'tag': '#9YPLQGQVC',
#        'fame': Decimal('1019')},
#       {'name': 'OhneZzZ',
#        'repairPoints': Decimal('0'),
#        'tag': '#2J2YL0CG',
#        'fame': Decimal('1020')},
#       {'name': 'zPrøtõçölòJr11',
#        'repairPoints': Decimal('0'),
#        'tag': '#LCUUVUJ2',
#        'fame': Decimal('1025')},
#       {'name': '⚡Héctor⚡7⚡',
#        'repairPoints': Decimal('0'),
#        'tag': '#90YV0GP9',
#        'fame': Decimal('1053')},
#       {'name': 'alex.rubio05',
#        'repairPoints': Decimal('0'),
#        'tag': '#L2UC8JC9',
#        'fame': Decimal('1071')},
#       {'name': 'Miguel Tablet',
#        'repairPoints': Decimal('0'),
#        'tag': '#90L2JUVCQ',
#        'fame': Decimal('1122')},
#       {'name': '₹₪Aegon₪₹',
#        'repairPoints': Decimal('0'),
#        'tag': '#RQ9CL0Q',
#        'fame': Decimal('1126')},
#       {'name': 'Zakrøn',
#        'repairPoints': Decimal('0'),
#        'tag': '#CRQU9YGP',
#        'fame': Decimal('1160')},
#       {'name': 'Fakeer',
#        'repairPoints': Decimal('0'),
#        'tag': '#9LYPRQCL',
#        'fame': Decimal('1168')},
#       {'name': 'imanol',
#        'repairPoints': Decimal('0'),
#        'tag': '#LJPUG99U',
#        'fame': Decimal('1194')},
#       {'name': 'ivanbauer5',
#        'repairPoints': Decimal('0'),
#        'tag': '#LUUYVCC8',
#        'fame': Decimal('1203')},
#       {'name': 'david77n',
#        'repairPoints': Decimal('0'),
#        'tag': '#9Q08CPUV',
#        'fame': Decimal('1221')},
#       {'name': 'mediometro',
#        'repairPoints': Decimal('0'),
#        'tag': '#82QLCUVQJ',
#        'fame': Decimal('1236')},
#       {'name': 'şeyma',
#        'repairPoints': Decimal('0'),
#        'tag': '#L0C8VLPQ8',
#        'fame': Decimal('1263')},
#       {'name': 'shiro',
#        'repairPoints': Decimal('0'),
#        'tag': '#8QGUJ89CC',
#        'fame': Decimal('1294')},
#       {'name': 'david',
#        'repairPoints': Decimal('0'),
#        'tag': '#2CR8CLULY',
#        'fame': Decimal('1295')},
#       {'name': 'Villis',
#        'repairPoints': Decimal('0'),
#        'tag': '#URQVQLQ9',
#        'fame': Decimal('1328')},
#       {'name': 'roal',
#        'repairPoints': Decimal('0'),
#        'tag': '#VQ0UJGG',
#        'fame': Decimal('1343')},
#       {'name': 'YERAY',
#        'repairPoints': Decimal('0'),
#        'tag': '#Q2RPLJ9L',
#        'fame': Decimal('1377')},
#       {'name': '..Dolz..',
#        'repairPoints': Decimal('0'),
#        'tag': '#8VGLVRPV',
#        'fame': Decimal('1512')},
#       {'name': 'Love Y-i Sanax',
#        'repairPoints': Decimal('0'),
#        'tag': '#G0LPGCG2',
#        'fame': Decimal('1545')},
#       {'name': 'nieto 5',
#        'repairPoints': Decimal('0'),
#        'tag': '#2J9CQ9P90',
#        'fame': Decimal('1568')},
#       {'name': 'pezcozon',
#        'repairPoints': Decimal('0'),
#        'tag': '#L999P0U2',
#        'fame': Decimal('1612')},
#       {'name': 'LEONES',
#        'repairPoints': Decimal('0'),
#        'tag': '#2YPR8JPY2',
#        'fame': Decimal('1638')},
#       {'name': 'Breezy',
#        'repairPoints': Decimal('0'),
#        'tag': '#RU0LU828',
#        'fame': Decimal('1685')},
#       {'name': 'Pinchito',
#        'repairPoints': Decimal('0'),
#        'tag': '#PJQY0PU',
#        'fame': Decimal('1723')},
#       {'name': 'Portoles99',
#        'repairPoints': Decimal('0'),
#        'tag': '#89U0PV00G',
#        'fame': Decimal('1751')},
#       {'name': 'arturo',
#        'repairPoints': Decimal('0'),
#        'tag': '#2GJ8JLLP0',
#        'fame': Decimal('1862')},
#       {'name': 'super lol',
#        'repairPoints': Decimal('0'),
#        'tag': '#PLRLCVC89',
#        'fame': Decimal('1873')},
#       {'name': 'GOD OF LOL',
#        'repairPoints': Decimal('0'),
#        'tag': '#9G89PRQ00',
#        'fame': Decimal('1894')},
#       {'name': 'Molgar',
#        'repairPoints': Decimal('0'),
#        'tag': '#9PJRRVCLG',
#        'fame': Decimal('1895')},
#       {'name': 'Lord LoL',
#        'repairPoints': Decimal('0'),
#        'tag': '#2CCCQQCPJ',
#        'fame': Decimal('1924')},
#       {'name': 'n13to',
#        'repairPoints': Decimal('0'),
#        'tag': '#JRVVVJUJ',
#        'fame': Decimal('1928')},
#       {'name': 'Rufus Pelotus',
#        'repairPoints': Decimal('0'),
#        'tag': '#2JPQCV9V9',
#        'fame': Decimal('1948')},
#       {'name': 'Manuel',
#        'repairPoints': Decimal('0'),
#        'tag': '#220GGLJ2R',
#        'fame': Decimal('1951')},
#       {'name': 'makamen74',
#        'repairPoints': Decimal('0'),
#        'tag': '#8RGV208C8',
#        'fame': Decimal('1960')}]},
#     {'finishTime': '20201104T061740.000Z',
#      'badgeId': Decimal('16000002'),
#      'name': 'Black Hog down',
#      'repairPoints': Decimal('0'),
#      'tag': '#9LVYUL8Q',
#      'clanScore': Decimal('3245'),
#      'fame': Decimal('55042'),
#      'participants': [{'name': 'BHD l Muetze',
#        'repairPoints': Decimal('0'),
#        'tag': '#VPY02RRU',
#        'fame': Decimal('0')},
#       {'name': 'AdrianBoss',
#        'repairPoints': Decimal('0'),
#        'tag': '#JYGRGVJQ',
#        'fame': Decimal('0')},
#       {'name': 'BHD I Laktros',
#        'repairPoints': Decimal('0'),
#        'tag': '#2GRGVC2QY',
#        'fame': Decimal('0')},
#       {'name': 'Godmodex',
#        'repairPoints': Decimal('0'),
#        'tag': '#8YP0VQLPU',
#        'fame': Decimal('102')},
#       {'name': 'pumpfschlumpf',
#        'repairPoints': Decimal('0'),
#        'tag': '#PC9PCC2G',
#        'fame': Decimal('367')},
#       {'name': 'Blackyi',
#        'repairPoints': Decimal('0'),
#        'tag': '#2Y80G20J',
#        'fame': Decimal('393')},
#       {'name': 'AgentOrange',
#        'repairPoints': Decimal('0'),
#        'tag': '#9RG20G9CV',
#        'fame': Decimal('452')},
#       {'name': 'Chreys',
#        'repairPoints': Decimal('0'),
#        'tag': '#8VVP8RP90',
#        'fame': Decimal('503')},
#       {'name': 'Z$○Lt',
#        'repairPoints': Decimal('0'),
#        'tag': '#2LV0Y0PP',
#        'fame': Decimal('600')},
#       {'name': '<c4>Bo$$',
#        'repairPoints': Decimal('0'),
#        'tag': '#P0PLCU0R0',
#        'fame': Decimal('610')},
#       {'name': 'Taste Osteron',
#        'repairPoints': Decimal('0'),
#        'tag': '#8QVPRJRV',
#        'fame': Decimal('622')},
#       {'name': 'philipp',
#        'repairPoints': Decimal('0'),
#        'tag': '#2R0L9YR',
#        'fame': Decimal('761')},
#       {'name': 'BRJT01',
#        'repairPoints': Decimal('0'),
#        'tag': '#8RRRQRQJ',
#        'fame': Decimal('776')},
#       {'name': 'elyesa',
#        'repairPoints': Decimal('0'),
#        'tag': '#2QP8JV8C',
#        'fame': Decimal('784')},
#       {'name': 'rene',
#        'repairPoints': Decimal('0'),
#        'tag': '#89P9QGJ99',
#        'fame': Decimal('793')},
#       {'name': 'Nico',
#        'repairPoints': Decimal('0'),
#        'tag': '#8UUCJG8JY',
#        'fame': Decimal('810')},
#       {'name': 'Mabidi',
#        'repairPoints': Decimal('0'),
#        'tag': '#RRJJYRRP',
#        'fame': Decimal('869')},
#       {'name': 'BHD I centenz',
#        'repairPoints': Decimal('0'),
#        'tag': '#8GLR809LY',
#        'fame': Decimal('916')},
#       {'name': 'Phill1703',
#        'repairPoints': Decimal('0'),
#        'tag': '#89GVLP2R',
#        'fame': Decimal('925')},
#       {'name': 'Achi',
#        'repairPoints': Decimal('0'),
#        'tag': '#90PLCJ8LJ',
#        'fame': Decimal('1082')},
#       {'name': 'Engel 2.0',
#        'repairPoints': Decimal('0'),
#        'tag': '#8C2RVPQQV',
#        'fame': Decimal('1086')},
#       {'name': 'Floki',
#        'repairPoints': Decimal('0'),
#        'tag': '#89JJPGYGC',
#        'fame': Decimal('1091')},
#       {'name': '<c6>BHDIBo$$',
#        'repairPoints': Decimal('0'),
#        'tag': '#2CLU9VV2Q',
#        'fame': Decimal('1109')},
#       {'name': 'BHD I Captain',
#        'repairPoints': Decimal('0'),
#        'tag': '#2VU9PJ99V',
#        'fame': Decimal('1142')},
#       {'name': 'BlauesAuge',
#        'repairPoints': Decimal('0'),
#        'tag': '#9UVVCYUU',
#        'fame': Decimal('1179')},
#       {'name': 'Endless Hope',
#        'repairPoints': Decimal('0'),
#        'tag': '#229P8PU9Y',
#        'fame': Decimal('1277')},
#       {'name': 'coriander',
#        'repairPoints': Decimal('0'),
#        'tag': '#P8GJ09UJ',
#        'fame': Decimal('1284')},
#       {'name': 'ixiii',
#        'repairPoints': Decimal('0'),
#        'tag': '#2VP0L98CR',
#        'fame': Decimal('1313')},
#       {'name': 'BHD I McFly',
#        'repairPoints': Decimal('0'),
#        'tag': '#2Y9LGPLUQ',
#        'fame': Decimal('1314')},
#       {'name': 'BHD I gundiline',
#        'repairPoints': Decimal('0'),
#        'tag': '#P2C2JCR8',
#        'fame': Decimal('1322')},
#       {'name': 'Pattirix',
#        'repairPoints': Decimal('0'),
#        'tag': '#802CUY0R',
#        'fame': Decimal('1342')},
#       {'name': 'Zaaaacckk',
#        'repairPoints': Decimal('0'),
#        'tag': '#VYC2QVCQ',
#        'fame': Decimal('1449')},
#       {'name': 'BHD I ENGEL',
#        'repairPoints': Decimal('0'),
#        'tag': '#22C8G9Q0V',
#        'fame': Decimal('1521')},
#       {'name': 'Just_Laura',
#        'repairPoints': Decimal('0'),
#        'tag': '#PY0U9RC2G',
#        'fame': Decimal('1608')},
#       {'name': 'Dresche',
#        'repairPoints': Decimal('0'),
#        'tag': '#8PJVYLUYJ',
#        'fame': Decimal('1653')},
#       {'name': 'BHD I Yoshi',
#        'repairPoints': Decimal('0'),
#        'tag': '#8V8PGYYVP',
#        'fame': Decimal('1664')},
#       {'name': 'BHD l Mocheck1',
#        'repairPoints': Decimal('0'),
#        'tag': '#2PUP99LL',
#        'fame': Decimal('1732')},
#       {'name': 'HuyPham',
#        'repairPoints': Decimal('0'),
#        'tag': '#PRCJ90QG',
#        'fame': Decimal('1777')},
#       {'name': 'Yökai-Dämon',
#        'repairPoints': Decimal('0'),
#        'tag': '#88UQYQVC0',
#        'fame': Decimal('1805')},
#       {'name': 'Apollo',
#        'repairPoints': Decimal('0'),
#        'tag': '#JV28Q22R',
#        'fame': Decimal('1826')},
#       {'name': 'Mikus',
#        'repairPoints': Decimal('0'),
#        'tag': '#88GY80GQQ',
#        'fame': Decimal('1856')},
#       {'name': 'DerUncle',
#        'repairPoints': Decimal('0'),
#        'tag': '#8YL09LVV',
#        'fame': Decimal('1864')},
#       {'name': 'Any',
#        'repairPoints': Decimal('0'),
#        'tag': '#89JGP8C0V',
#        'fame': Decimal('1961')},
#       {'name': 'BHD l Matze92',
#        'repairPoints': Decimal('0'),
#        'tag': '#2VQ0URPGC',
#        'fame': Decimal('2025')},
#       {'name': 'Dasty13',
#        'repairPoints': Decimal('0'),
#        'tag': '#20UJQJUJG',
#        'fame': Decimal('2041')},
#       {'name': 'BHD I Dini',
#        'repairPoints': Decimal('0'),
#        'tag': '#8G8GLQVPG',
#        'fame': Decimal('2121')},
#       {'name': 'zsolt',
#        'repairPoints': Decimal('0'),
#        'tag': '#90L8JCVYR',
#        'fame': Decimal('2278')}]},
#     {'finishTime': '20201104T060456.000Z',
#      'badgeId': Decimal('16000128'),
#      'name': '(((o(*ﾟ▽ﾟ*)o)))',
#      'repairPoints': Decimal('0'),
#      'tag': '#8L90V9V',
#      'clanScore': Decimal('3260'),
#      'fame': Decimal('52205'),
#      'participants': [{'name': '那咋办',
#        'repairPoints': Decimal('0'),
#        'tag': '#UGJGL0G8',
#        'fame': Decimal('0')},
#       {'name': '图图',
#        'repairPoints': Decimal('0'),
#        'tag': '#VPC2PCU0',
#        'fame': Decimal('0')},
#       {'name': '⚡️Storm⚡️',
#        'repairPoints': Decimal('0'),
#        'tag': '#QLU0GLU9Q',
#        'fame': Decimal('0')},
#       {'name': '红梅傲骨',
#        'repairPoints': Decimal('0'),
#        'tag': '#9QCUY0V82',
#        'fame': Decimal('310')},
#       {'name': '空白的回忆',
#        'repairPoints': Decimal('0'),
#        'tag': '#CLYYQYJL',
#        'fame': Decimal('385')},
#       {'name': '成全',
#        'repairPoints': Decimal('0'),
#        'tag': '#JLLVVCVV',
#        'fame': Decimal('402')},
#       {'name': 'smile kuan',
#        'repairPoints': Decimal('0'),
#        'tag': '#2CU9L09Q2',
#        'fame': Decimal('416')},
#       {'name': '乘风破浪',
#        'repairPoints': Decimal('0'),
#        'tag': '#JU28CQVQ',
#        'fame': Decimal('514')},
#       {'name': 'Y_Y',
#        'repairPoints': Decimal('0'),
#        'tag': '#YVVPUCUQ',
#        'fame': Decimal('520')},
#       {'name': '愚公丶',
#        'repairPoints': Decimal('0'),
#        'tag': '#9PU9R0JYL',
#        'fame': Decimal('596')},
#       {'name': 'Overdose',
#        'repairPoints': Decimal('0'),
#        'tag': '#PLYCU9RC',
#        'fame': Decimal('701')},
#       {'name': '是聪明小刘不是笨蛋小刘',
#        'repairPoints': Decimal('0'),
#        'tag': '#8Q0L922CU',
#        'fame': Decimal('888')},
#       {'name': '呵呵lcsmt',
#        'repairPoints': Decimal('0'),
#        'tag': '#2LJG2UQJQ',
#        'fame': Decimal('922')},
#       {'name': '醉月逍遥•红尘仙',
#        'repairPoints': Decimal('0'),
#        'tag': '#8UVLUUYQC',
#        'fame': Decimal('936')},
#       {'name': '<c6>丹丹',
#        'repairPoints': Decimal('0'),
#        'tag': '#P22VRC0G0',
#        'fame': Decimal('965')},
#       {'name': 'boss yue',
#        'repairPoints': Decimal('0'),
#        'tag': '#YGPJRLQ8',
#        'fame': Decimal('1030')},
#       {'name': '全是智者',
#        'repairPoints': Decimal('0'),
#        'tag': '#JR9JR090',
#        'fame': Decimal('1038')},
#       {'name': '俺真的不是老虎',
#        'repairPoints': Decimal('0'),
#        'tag': '#YJJCL0LR',
#        'fame': Decimal('1040')},
#       {'name': '平凡的小屋',
#        'repairPoints': Decimal('0'),
#        'tag': '#Y082VVRL',
#        'fame': Decimal('1086')},
#       {'name': '沐荷丶恋景',
#        'repairPoints': Decimal('0'),
#        'tag': '#29Q9JQ0JV',
#        'fame': Decimal('1124')},
#       {'name': '老海鲜',
#        'repairPoints': Decimal('0'),
#        'tag': '#9LRCJV0LP',
#        'fame': Decimal('1135')},
#       {'name': 'MyTrashTeammate',
#        'repairPoints': Decimal('0'),
#        'tag': '#UP2PRYC0',
#        'fame': Decimal('1144')},
#       {'name': '毛酋长',
#        'repairPoints': Decimal('0'),
#        'tag': '#9YVV80U8',
#        'fame': Decimal('1144')},
#       {'name': '葬爱、炸屎',
#        'repairPoints': Decimal('0'),
#        'tag': '#CJRQC292',
#        'fame': Decimal('1194')},
#       {'name': '出现吧～皮卡丘',
#        'repairPoints': Decimal('0'),
#        'tag': '#222QPLC9',
#        'fame': Decimal('1210')},
#       {'name': '帅气的冷泡茶',
#        'repairPoints': Decimal('0'),
#        'tag': '#2L92YJR2Y',
#        'fame': Decimal('1224')},
#       {'name': '哀哩先森',
#        'repairPoints': Decimal('0'),
#        'tag': '#22PRQQ90G',
#        'fame': Decimal('1252')},
#       {'name': 'Therandom',
#        'repairPoints': Decimal('0'),
#        'tag': '#20UGLRYR2',
#        'fame': Decimal('1296')},
#       {'name': '不打盹',
#        'repairPoints': Decimal('0'),
#        'tag': '#Q8C9J2Y',
#        'fame': Decimal('1307')},
#       {'name': 'Barracuda',
#        'repairPoints': Decimal('0'),
#        'tag': '#L00JLL9QU',
#        'fame': Decimal('1313')},
#       {'name': '<c6>疯人院',
#        'repairPoints': Decimal('0'),
#        'tag': '#99YV0VCV',
#        'fame': Decimal('1352')},
#       {'name': '只打左塔',
#        'repairPoints': Decimal('0'),
#        'tag': '#80G9VP20Q',
#        'fame': Decimal('1429')},
#       {'name': 'octolive',
#        'repairPoints': Decimal('0'),
#        'tag': '#UP2PJUJ8',
#        'fame': Decimal('1456')},
#       {'name': '兔兔',
#        'repairPoints': Decimal('0'),
#        'tag': '#Y0C0QJY9',
#        'fame': Decimal('1456')},
#       {'name': '哦哦哦',
#        'repairPoints': Decimal('0'),
#        'tag': '#2YC9J0J0C',
#        'fame': Decimal('1456')},
#       {'name': 'Mike wang',
#        'repairPoints': Decimal('0'),
#        'tag': '#GQ0YPYYY',
#        'fame': Decimal('1671')},
#       {'name': 'liu',
#        'repairPoints': Decimal('0'),
#        'tag': '#92YGQ92G',
#        'fame': Decimal('1718')},
#       {'name': '酷鱼',
#        'repairPoints': Decimal('0'),
#        'tag': '#9YP28VQ9',
#        'fame': Decimal('1719')},
#       {'name': '<c6>传奇丶BaBy',
#        'repairPoints': Decimal('0'),
#        'tag': '#YV2CJUVR2',
#        'fame': Decimal('1740')},
#       {'name': '不吃辣条i',
#        'repairPoints': Decimal('0'),
#        'tag': '#R999Q009',
#        'fame': Decimal('1749')},
#       {'name': '藤原跳海',
#        'repairPoints': Decimal('0'),
#        'tag': '#8G9VLVLCG',
#        'fame': Decimal('1814')},
#       {'name': '拉风小钢炮',
#        'repairPoints': Decimal('0'),
#        'tag': '#L88GLP00',
#        'fame': Decimal('2062')},
#       {'name': '哑述',
#        'repairPoints': Decimal('0'),
#        'tag': '#2YU0RPYG',
#        'fame': Decimal('2071')},
#       {'name': '痛苦魔师真空上阵',
#        'repairPoints': Decimal('0'),
#        'tag': '#8LY9CVU2J',
#        'fame': Decimal('2343')}]},
#     {'finishTime': '20201104T053720.000Z',
#      'badgeId': Decimal('16000154'),
#      'name': '#SAVAGE OCTOPUS',
#      'repairPoints': Decimal('0'),
#      'tag': '#GPR2JUQ',
#      'clanScore': Decimal('3270'),
#      'fame': Decimal('52944'),
#      'participants': [{'name': 'deke',
#        'repairPoints': Decimal('0'),
#        'tag': '#89RCVQ9RG',
#        'fame': Decimal('0')},
#       {'name': 'AlexPrince',
#        'repairPoints': Decimal('0'),
#        'tag': '#889YULY2P',
#        'fame': Decimal('0')},
#       {'name': 'Basher',
#        'repairPoints': Decimal('0'),
#        'tag': '#PR28UJGJR',
#        'fame': Decimal('0')},
#       {'name': 'Kalypso♋',
#        'repairPoints': Decimal('0'),
#        'tag': '#PR0228R8',
#        'fame': Decimal('208')},
#       {'name': 'LeggoMyEggo',
#        'repairPoints': Decimal('0'),
#        'tag': '#9YPY00JY',
#        'fame': Decimal('407')},
#       {'name': '☘️☘️☘️☘️☘️',
#        'repairPoints': Decimal('0'),
#        'tag': '#9VJPP08VC',
#        'fame': Decimal('492')},
#       {'name': '#SO King Krabby',
#        'repairPoints': Decimal('0'),
#        'tag': '#8YQY0JUP',
#        'fame': Decimal('505')},
#       {'name': 'amb',
#        'repairPoints': Decimal('0'),
#        'tag': '#UJL02PUP',
#        'fame': Decimal('517')},
#       {'name': '4lb3rt',
#        'repairPoints': Decimal('0'),
#        'tag': '#899JGCCPJ',
#        'fame': Decimal('613')},
#       {'name': 'Hofee',
#        'repairPoints': Decimal('0'),
#        'tag': '#2P9LQYUV',
#        'fame': Decimal('684')},
#       {'name': 'Zambie:)',
#        'repairPoints': Decimal('0'),
#        'tag': '#JPRUR9VV',
#        'fame': Decimal('693')},
#       {'name': '<c1>MANE',
#        'repairPoints': Decimal('0'),
#        'tag': '#8LY9YLVJQ',
#        'fame': Decimal('810')},
#       {'name': 'PrinceFrederick',
#        'repairPoints': Decimal('0'),
#        'tag': '#9Q22RVGJ',
#        'fame': Decimal('823')},
#       {'name': 'Mouf',
#        'repairPoints': Decimal('0'),
#        'tag': '#8L88PQQY',
#        'fame': Decimal('842')},
#       {'name': 'HectorDaNector',
#        'repairPoints': Decimal('0'),
#        'tag': '#Q8R09VP',
#        'fame': Decimal('892')},
#       {'name': 'crazy',
#        'repairPoints': Decimal('0'),
#        'tag': '#LUG8UG9L',
#        'fame': Decimal('901')},
#       {'name': 'GABRIEL :v',
#        'repairPoints': Decimal('0'),
#        'tag': '#2YJV0PUCC',
#        'fame': Decimal('963')},
#       {'name': 'mooseknuckles',
#        'repairPoints': Decimal('0'),
#        'tag': '#28LLP80CL',
#        'fame': Decimal('984')},
#       {'name': 'gus',
#        'repairPoints': Decimal('0'),
#        'tag': '#L0YUJQQU',
#        'fame': Decimal('986')},
#       {'name': 'Zoroth',
#        'repairPoints': Decimal('0'),
#        'tag': '#88RJ20LL',
#        'fame': Decimal('1030')},
#       {'name': 'N.T.L',
#        'repairPoints': Decimal('0'),
#        'tag': '#R8CYQQ8',
#        'fame': Decimal('1127')},
#       {'name': 'fadedsun',
#        'repairPoints': Decimal('0'),
#        'tag': '#2LQ29JY9Y',
#        'fame': Decimal('1134')},
#       {'name': 'Gabino',
#        'repairPoints': Decimal('0'),
#        'tag': '#9CUP08J2',
#        'fame': Decimal('1144')},
#       {'name': 'Codi',
#        'repairPoints': Decimal('0'),
#        'tag': '#9CVYJ8QL',
#        'fame': Decimal('1173')},
#       {'name': 'HankMccoy',
#        'repairPoints': Decimal('0'),
#        'tag': '#V2UCPRLJ',
#        'fame': Decimal('1196')},
#       {'name': 'batninja',
#        'repairPoints': Decimal('0'),
#        'tag': '#22C08RP9L',
#        'fame': Decimal('1224')},
#       {'name': 'All_Things_Pnw',
#        'repairPoints': Decimal('0'),
#        'tag': '#2UQJJQPV',
#        'fame': Decimal('1237')},
#       {'name': 'T-Rid',
#        'repairPoints': Decimal('0'),
#        'tag': '#9J9QL9L8',
#        'fame': Decimal('1239')},
#       {'name': 'updog',
#        'repairPoints': Decimal('0'),
#        'tag': '#2J998UR99',
#        'fame': Decimal('1245')},
#       {'name': 'Classy Assassin',
#        'repairPoints': Decimal('0'),
#        'tag': '#9Q9YJQY08',
#        'fame': Decimal('1301')},
#       {'name': 'GucciAlfredo',
#        'repairPoints': Decimal('0'),
#        'tag': '#2RJUVVVG2',
#        'fame': Decimal('1304')},
#       {'name': 'MotionTrap',
#        'repairPoints': Decimal('0'),
#        'tag': '#8J29PC8J',
#        'fame': Decimal('1318')},
#       {'name': 'Savage',
#        'repairPoints': Decimal('0'),
#        'tag': '#YGYY8GCY8',
#        'fame': Decimal('1318')},
#       {'name': 'brandon',
#        'repairPoints': Decimal('0'),
#        'tag': '#P0P80YJ8',
#        'fame': Decimal('1328')},
#       {'name': 'mikehawk',
#        'repairPoints': Decimal('0'),
#        'tag': '#PPCCV99GR',
#        'fame': Decimal('1400')},
#       {'name': 'andrewnett',
#        'repairPoints': Decimal('0'),
#        'tag': '#2L2YP8UC2',
#        'fame': Decimal('1438')},
#       {'name': 'Marqueezy',
#        'repairPoints': Decimal('0'),
#        'tag': '#2RJ0G8YL',
#        'fame': Decimal('1509')},
#       {'name': 'jpfanatic',
#        'repairPoints': Decimal('0'),
#        'tag': '#8Y20GP9J',
#        'fame': Decimal('1548')},
#       {'name': 'Krystorr',
#        'repairPoints': Decimal('0'),
#        'tag': '#L0G280JY',
#        'fame': Decimal('1560')},
#       {'name': 'ClassyBarbarian',
#        'repairPoints': Decimal('0'),
#        'tag': '#2LRP8YC8G',
#        'fame': Decimal('1584')},
#       {'name': 'ImSoBuilt',
#        'repairPoints': Decimal('0'),
#        'tag': '#PPLRJ2C',
#        'fame': Decimal('1599')},
#       {'name': 'dream',
#        'repairPoints': Decimal('0'),
#        'tag': '#2V9LVLQY',
#        'fame': Decimal('1614')},
#       {'name': 'brnurshps',
#        'repairPoints': Decimal('0'),
#        'tag': '#GQCGJY9J',
#        'fame': Decimal('1644')},
#       {'name': 'krispytreats',
#        'repairPoints': Decimal('0'),
#        'tag': '#Q08QJJJ8',
#        'fame': Decimal('1724')},
#       {'name': 'SuperSamoanBlue',
#        'repairPoints': Decimal('0'),
#        'tag': '#90CRR28Q',
#        'fame': Decimal('1853')},
#       {'name': 'ESchalton',
#        'repairPoints': Decimal('0'),
#        'tag': '#2G9V8P2PJ',
#        'fame': Decimal('1854')},
#       {'name': 'Wolfy',
#        'repairPoints': Decimal('0'),
#        'tag': '#202PVQRUP',
#        'fame': Decimal('1971')},
#       {'name': 'Bruce',
#        'repairPoints': Decimal('0'),
#        'tag': '#VQ8PY8VR',
#        'fame': Decimal('2008')}]},
#     {'badgeId': Decimal('16000114'),
#      'name': 'clash oholics',
#      'repairPoints': Decimal('0'),
#      'tag': '#99RQJ0G8',
#      'clanScore': Decimal('3235'),
#      'fame': Decimal('48465'),
#      'participants': [{'name': 'DoFu',
#        'repairPoints': Decimal('0'),
#        'tag': '#LVV2U8VYJ',
#        'fame': Decimal('0')},
#       {'name': 'Raphaël',
#        'repairPoints': Decimal('0'),
#        'tag': '#880CGLCR',
#        'fame': Decimal('0')},
#       {'name': 'kevin09',
#        'repairPoints': Decimal('0'),
#        'tag': '#GR9PYJU8',
#        'fame': Decimal('340')},
#       {'name': 'Rageiz4tacos',
#        'repairPoints': Decimal('0'),
#        'tag': '#Q8CJLLJYU',
#        'fame': Decimal('388')},
#       {'name': 'XSV21',
#        'repairPoints': Decimal('0'),
#        'tag': '#RVQV0UL',
#        'fame': Decimal('389')},
#       {'name': 'UnrealYoshi25',
#        'repairPoints': Decimal('0'),
#        'tag': '#8PQQ88RP',
#        'fame': Decimal('406')},
#       {'name': 'SanJua12',
#        'repairPoints': Decimal('0'),
#        'tag': '#8UY22P2P8',
#        'fame': Decimal('438')},
#       {'name': 'Trainer Bra',
#        'repairPoints': Decimal('0'),
#        'tag': '#PCC8J0PGJ',
#        'fame': Decimal('484')},
#       {'name': 'Raj',
#        'repairPoints': Decimal('0'),
#        'tag': '#229VR9GC0',
#        'fame': Decimal('520')},
#       {'name': 'bmcbeastmode',
#        'repairPoints': Decimal('0'),
#        'tag': '#2Q0C9JQ8C',
#        'fame': Decimal('554')},
#       {'name': 'Aroos_',
#        'repairPoints': Decimal('0'),
#        'tag': '#902JJ8LGP',
#        'fame': Decimal('604')},
#       {'name': 'HellzOdin',
#        'repairPoints': Decimal('0'),
#        'tag': '#2ULCYYPQ',
#        'fame': Decimal('623')},
#       {'name': 'SingerBud',
#        'repairPoints': Decimal('0'),
#        'tag': '#C2P98G',
#        'fame': Decimal('746')},
#       {'name': 'Jeff',
#        'repairPoints': Decimal('0'),
#        'tag': '#98L8LJUY',
#        'fame': Decimal('762')},
#       {'name': 'awsomeGod',
#        'repairPoints': Decimal('0'),
#        'tag': '#YJ0GCC9Q',
#        'fame': Decimal('770')},
#       {'name': 'POTTY',
#        'repairPoints': Decimal('0'),
#        'tag': '#8VP80P28C',
#        'fame': Decimal('867')},
#       {'name': 'littleBro24',
#        'repairPoints': Decimal('0'),
#        'tag': '#PJP0L0PUC',
#        'fame': Decimal('933')},
#       {'name': 'Ashutosh',
#        'repairPoints': Decimal('0'),
#        'tag': '#82RYP90CY',
#        'fame': Decimal('1009')},
#       {'name': 'MAHDI',
#        'repairPoints': Decimal('0'),
#        'tag': '#Q92Y2C9CU',
#        'fame': Decimal('1024')},
#       {'name': 'oirsyad',
#        'repairPoints': Decimal('0'),
#        'tag': '#9Y99P2JUG',
#        'fame': Decimal('1025')},
#       {'name': 'miki',
#        'repairPoints': Decimal('0'),
#        'tag': '#8V88VPL8J',
#        'fame': Decimal('1033')},
#       {'name': 'Royale IX',
#        'repairPoints': Decimal('0'),
#        'tag': '#982PJQ8PQ',
#        'fame': Decimal('1047')},
#       {'name': 'gofft',
#        'repairPoints': Decimal('0'),
#        'tag': '#9LJ9QJRY',
#        'fame': Decimal('1096')},
#       {'name': 'lab monkey',
#        'repairPoints': Decimal('0'),
#        'tag': '#8URGCG2UR',
#        'fame': Decimal('1112')},
#       {'name': 'ema',
#        'repairPoints': Decimal('0'),
#        'tag': '#9GU229Y9G',
#        'fame': Decimal('1180')},
#       {'name': 'miki',
#        'repairPoints': Decimal('0'),
#        'tag': '#90LU20JQC',
#        'fame': Decimal('1182')},
#       {'name': 'eulien',
#        'repairPoints': Decimal('0'),
#        'tag': '#80CQQUR99',
#        'fame': Decimal('1206')},
#       {'name': 'Bizz2',
#        'repairPoints': Decimal('0'),
#        'tag': '#22LRJCRVQ',
#        'fame': Decimal('1209')},
#       {'name': 'bluetack',
#        'repairPoints': Decimal('0'),
#        'tag': '#R8JYRGLY',
#        'fame': Decimal('1215')},
#       {'name': 'kevin09',
#        'repairPoints': Decimal('0'),
#        'tag': '#LPRV828U',
#        'fame': Decimal('1279')},
#       {'name': 'Tig Ol Bitty',
#        'repairPoints': Decimal('0'),
#        'tag': '#22UG28002',
#        'fame': Decimal('1294')},
#       {'name': 'Leozinho',
#        'repairPoints': Decimal('0'),
#        'tag': '#YLG98VRL',
#        'fame': Decimal('1300')},
#       {'name': 'Jake 937',
#        'repairPoints': Decimal('0'),
#        'tag': '#8L8LU9RU',
#        'fame': Decimal('1352')},
#       {'name': 'burr',
#        'repairPoints': Decimal('0'),
#        'tag': '#9UR920VC',
#        'fame': Decimal('1409')},
#       {'name': 'mickymazz',
#        'repairPoints': Decimal('0'),
#        'tag': '#CP0UJQYR',
#        'fame': Decimal('1429')},
#       {'name': 'bensuperman',
#        'repairPoints': Decimal('0'),
#        'tag': '#90PVV9J8P',
#        'fame': Decimal('1435')},
#       {'name': 'dhivakar',
#        'repairPoints': Decimal('0'),
#        'tag': '#20YGJRQYR',
#        'fame': Decimal('1436')},
#       {'name': 'Elmo',
#        'repairPoints': Decimal('0'),
#        'tag': '#82PYYCLGY',
#        'fame': Decimal('1512')},
#       {'name': 'tylerbo',
#        'repairPoints': Decimal('0'),
#        'tag': '#8LVPVUJ',
#        'fame': Decimal('1537')},
#       {'name': '1st vandezande',
#        'repairPoints': Decimal('0'),
#        'tag': '#2Y892QYR',
#        'fame': Decimal('1552')},
#       {'name': 'TJ',
#        'repairPoints': Decimal('0'),
#        'tag': '#8CPU9VPQR',
#        'fame': Decimal('1663')},
#       {'name': 'Captain Tsubasa',
#        'repairPoints': Decimal('0'),
#        'tag': '#88JLJ29CR',
#        'fame': Decimal('1772')},
#       {'name': 'siller',
#        'repairPoints': Decimal('0'),
#        'tag': '#L0LR8GUUC',
#        'fame': Decimal('1815')},
#       {'name': 'Jacintobro',
#        'repairPoints': Decimal('0'),
#        'tag': '#Y98Y0UU2',
#        'fame': Decimal('1891')},
#       {'name': 'Ugachaka',
#        'repairPoints': Decimal('0'),
#        'tag': '#PRY2JVPL',
#        'fame': Decimal('1960')}]}],
#    'sectionIndex': Decimal('0'),
#    'state': 'full'}}]

# %% [markdown]
# # Who hasn't contibuted, from our clan

# %%
# take a look at what keys are in each record
data[0]['data'].keys()
# Out:
# dict_keys(['clan', 'clans', 'sectionIndex', 'state'])

# %%
data[0]['data']['clan'].keys()
# Out:
# dict_keys(['finishTime', 'badgeId', 'name', 'repairPoints', 'tag', 'clanScore', 'fame', 'participants'])

# %%
# Note here the finishTime is when the clan crossed the line -- that'll be helpful for some things

# %%
# I'm really interested in the participants

# %%
data[0]['data']['clan']['participants']
# Out:
# [{'name': 'deke',
#   'repairPoints': Decimal('0'),
#   'tag': '#89RCVQ9RG',
#   'fame': Decimal('0')},
#  {'name': 'AlexPrince',
#   'repairPoints': Decimal('0'),
#   'tag': '#889YULY2P',
#   'fame': Decimal('0')},
#  {'name': 'Basher',
#   'repairPoints': Decimal('0'),
#   'tag': '#PR28UJGJR',
#   'fame': Decimal('0')},
#  {'name': 'Kalypso♋',
#   'repairPoints': Decimal('0'),
#   'tag': '#PR0228R8',
#   'fame': Decimal('208')},
#  {'name': 'LeggoMyEggo',
#   'repairPoints': Decimal('0'),
#   'tag': '#9YPY00JY',
#   'fame': Decimal('407')},
#  {'name': '☘️☘️☘️☘️☘️',
#   'repairPoints': Decimal('0'),
#   'tag': '#9VJPP08VC',
#   'fame': Decimal('492')},
#  {'name': '#SO King Krabby',
#   'repairPoints': Decimal('0'),
#   'tag': '#8YQY0JUP',
#   'fame': Decimal('505')},
#  {'name': 'amb',
#   'repairPoints': Decimal('0'),
#   'tag': '#UJL02PUP',
#   'fame': Decimal('517')},
#  {'name': '4lb3rt',
#   'repairPoints': Decimal('0'),
#   'tag': '#899JGCCPJ',
#   'fame': Decimal('613')},
#  {'name': 'Hofee',
#   'repairPoints': Decimal('0'),
#   'tag': '#2P9LQYUV',
#   'fame': Decimal('684')},
#  {'name': 'Zambie:)',
#   'repairPoints': Decimal('0'),
#   'tag': '#JPRUR9VV',
#   'fame': Decimal('693')},
#  {'name': '<c1>MANE',
#   'repairPoints': Decimal('0'),
#   'tag': '#8LY9YLVJQ',
#   'fame': Decimal('810')},
#  {'name': 'PrinceFrederick',
#   'repairPoints': Decimal('0'),
#   'tag': '#9Q22RVGJ',
#   'fame': Decimal('823')},
#  {'name': 'Mouf',
#   'repairPoints': Decimal('0'),
#   'tag': '#8L88PQQY',
#   'fame': Decimal('842')},
#  {'name': 'HectorDaNector',
#   'repairPoints': Decimal('0'),
#   'tag': '#Q8R09VP',
#   'fame': Decimal('892')},
#  {'name': 'crazy',
#   'repairPoints': Decimal('0'),
#   'tag': '#LUG8UG9L',
#   'fame': Decimal('901')},
#  {'name': 'GABRIEL :v',
#   'repairPoints': Decimal('0'),
#   'tag': '#2YJV0PUCC',
#   'fame': Decimal('963')},
#  {'name': 'mooseknuckles',
#   'repairPoints': Decimal('0'),
#   'tag': '#28LLP80CL',
#   'fame': Decimal('984')},
#  {'name': 'gus',
#   'repairPoints': Decimal('0'),
#   'tag': '#L0YUJQQU',
#   'fame': Decimal('986')},
#  {'name': 'Zoroth',
#   'repairPoints': Decimal('0'),
#   'tag': '#88RJ20LL',
#   'fame': Decimal('1030')},
#  {'name': 'N.T.L',
#   'repairPoints': Decimal('0'),
#   'tag': '#R8CYQQ8',
#   'fame': Decimal('1127')},
#  {'name': 'fadedsun',
#   'repairPoints': Decimal('0'),
#   'tag': '#2LQ29JY9Y',
#   'fame': Decimal('1134')},
#  {'name': 'Gabino',
#   'repairPoints': Decimal('0'),
#   'tag': '#9CUP08J2',
#   'fame': Decimal('1144')},
#  {'name': 'Codi',
#   'repairPoints': Decimal('0'),
#   'tag': '#9CVYJ8QL',
#   'fame': Decimal('1173')},
#  {'name': 'HankMccoy',
#   'repairPoints': Decimal('0'),
#   'tag': '#V2UCPRLJ',
#   'fame': Decimal('1196')},
#  {'name': 'batninja',
#   'repairPoints': Decimal('0'),
#   'tag': '#22C08RP9L',
#   'fame': Decimal('1224')},
#  {'name': 'All_Things_Pnw',
#   'repairPoints': Decimal('0'),
#   'tag': '#2UQJJQPV',
#   'fame': Decimal('1237')},
#  {'name': 'T-Rid',
#   'repairPoints': Decimal('0'),
#   'tag': '#9J9QL9L8',
#   'fame': Decimal('1239')},
#  {'name': 'updog',
#   'repairPoints': Decimal('0'),
#   'tag': '#2J998UR99',
#   'fame': Decimal('1245')},
#  {'name': 'Classy Assassin',
#   'repairPoints': Decimal('0'),
#   'tag': '#9Q9YJQY08',
#   'fame': Decimal('1301')},
#  {'name': 'GucciAlfredo',
#   'repairPoints': Decimal('0'),
#   'tag': '#2RJUVVVG2',
#   'fame': Decimal('1304')},
#  {'name': 'MotionTrap',
#   'repairPoints': Decimal('0'),
#   'tag': '#8J29PC8J',
#   'fame': Decimal('1318')},
#  {'name': 'Savage',
#   'repairPoints': Decimal('0'),
#   'tag': '#YGYY8GCY8',
#   'fame': Decimal('1318')},
#  {'name': 'brandon',
#   'repairPoints': Decimal('0'),
#   'tag': '#P0P80YJ8',
#   'fame': Decimal('1328')},
#  {'name': 'mikehawk',
#   'repairPoints': Decimal('0'),
#   'tag': '#PPCCV99GR',
#   'fame': Decimal('1400')},
#  {'name': 'andrewnett',
#   'repairPoints': Decimal('0'),
#   'tag': '#2L2YP8UC2',
#   'fame': Decimal('1438')},
#  {'name': 'Marqueezy',
#   'repairPoints': Decimal('0'),
#   'tag': '#2RJ0G8YL',
#   'fame': Decimal('1509')},
#  {'name': 'jpfanatic',
#   'repairPoints': Decimal('0'),
#   'tag': '#8Y20GP9J',
#   'fame': Decimal('1548')},
#  {'name': 'Krystorr',
#   'repairPoints': Decimal('0'),
#   'tag': '#L0G280JY',
#   'fame': Decimal('1560')},
#  {'name': 'ClassyBarbarian',
#   'repairPoints': Decimal('0'),
#   'tag': '#2LRP8YC8G',
#   'fame': Decimal('1584')},
#  {'name': 'ImSoBuilt',
#   'repairPoints': Decimal('0'),
#   'tag': '#PPLRJ2C',
#   'fame': Decimal('1599')},
#  {'name': 'dream',
#   'repairPoints': Decimal('0'),
#   'tag': '#2V9LVLQY',
#   'fame': Decimal('1614')},
#  {'name': 'brnurshps',
#   'repairPoints': Decimal('0'),
#   'tag': '#GQCGJY9J',
#   'fame': Decimal('1644')},
#  {'name': 'krispytreats',
#   'repairPoints': Decimal('0'),
#   'tag': '#Q08QJJJ8',
#   'fame': Decimal('1724')},
#  {'name': 'SuperSamoanBlue',
#   'repairPoints': Decimal('0'),
#   'tag': '#90CRR28Q',
#   'fame': Decimal('1853')},
#  {'name': 'ESchalton',
#   'repairPoints': Decimal('0'),
#   'tag': '#2G9V8P2PJ',
#   'fame': Decimal('1854')},
#  {'name': 'Wolfy',
#   'repairPoints': Decimal('0'),
#   'tag': '#202PVQRUP',
#   'fame': Decimal('1971')},
#  {'name': 'Bruce',
#   'repairPoints': Decimal('0'),
#   'tag': '#VQ8PY8VR',
#   'fame': Decimal('2008')}]

# %%
#I don't really care to split out repair points & fame

# %%
reformattdData = {}
for record in data:
    if record['pullTime'] not in reformattdData:
        reformattdData[record['pullTime']] = {}
    for participant in record['data']['clan']['participants']:
        reformattdData[record['pullTime']][participant['name']] = participant.get('fame', 0) + participant.get('repairPoints', 0)

# %%
# Take a look at our restructured data:
reformattdData
# Out:
# {'2020-11-04T15:57:46.923597': {'deke': Decimal('0'),
#   'AlexPrince': Decimal('0'),
#   'Basher': Decimal('0'),
#   'Kalypso♋': Decimal('208'),
#   'LeggoMyEggo': Decimal('407'),
#   '☘️☘️☘️☘️☘️': Decimal('492'),
#   '#SO King Krabby': Decimal('505'),
#   'amb': Decimal('517'),
#   '4lb3rt': Decimal('613'),
#   'Hofee': Decimal('684'),
#   'Zambie:)': Decimal('693'),
#   '<c1>MANE': Decimal('810'),
#   'PrinceFrederick': Decimal('823'),
#   'Mouf': Decimal('842'),
#   'HectorDaNector': Decimal('892'),
#   'crazy': Decimal('901'),
#   'GABRIEL :v': Decimal('963'),
#   'mooseknuckles': Decimal('984'),
#   'gus': Decimal('986'),
#   'Zoroth': Decimal('1030'),
#   'N.T.L': Decimal('1127'),
#   'fadedsun': Decimal('1134'),
#   'Gabino': Decimal('1144'),
#   'Codi': Decimal('1173'),
#   'HankMccoy': Decimal('1196'),
#   'batninja': Decimal('1224'),
#   'All_Things_Pnw': Decimal('1237'),
#   'T-Rid': Decimal('1239'),
#   'updog': Decimal('1245'),
#   'Classy Assassin': Decimal('1301'),
#   'GucciAlfredo': Decimal('1304'),
#   'MotionTrap': Decimal('1318'),
#   'Savage': Decimal('1318'),
#   'brandon': Decimal('1328'),
#   'mikehawk': Decimal('1400'),
#   'andrewnett': Decimal('1438'),
#   'Marqueezy': Decimal('1509'),
#   'jpfanatic': Decimal('1548'),
#   'Krystorr': Decimal('1560'),
#   'ClassyBarbarian': Decimal('1584'),
#   'ImSoBuilt': Decimal('1599'),
#   'dream': Decimal('1614'),
#   'brnurshps': Decimal('1644'),
#   'krispytreats': Decimal('1724'),
#   'SuperSamoanBlue': Decimal('1853'),
#   'ESchalton': Decimal('1854'),
#   'Wolfy': Decimal('1971'),
#   'Bruce': Decimal('2008')}}

# %% [markdown]
# ### We'll bring in pandas to make it look pretty (think excel for python)
# ** Imports usually go at the top

# %%
import pandas as pd

# %%
myDF = pd.DataFrame(reformattdData)

# %%
earliestDate = list(reformattdData.keys())
earliestDate.sort()

# %%
# This is day 2 of the war, so for us -- anyone under ~800 (we'll call it 750) is a problem

# %%
myDF[myDF[earliestDate[-1]] < 750].sort_values(earliestDate[-1])
# Out:
#                 2020-11-04T15:57:46.923597
# AlexPrince                               0
# Basher                                   0
# deke                                     0
# Kalypso♋                               208
# LeggoMyEggo                            407
# ☘️☘️☘️☘️☘️                             492
# #SO King Krabby                        505
# amb                                    517
# 4lb3rt                                 613
# Hofee                                  684
# Zambie:)                               693
